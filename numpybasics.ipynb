# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

sum = a + b

print("Sum =", sum)
# Out:
# Enter first number:  2
# Enter second number:  3
# Sum = 5

# %%
import numpy as np

# %%
np.

# %%
a = np.array([1,2,3,4])
print(a)
# Out:
# [1 2 3 4]

# %%
a = np.zeros(5)
print(a)
# Out:
# [0. 0. 0. 0. 0.]

# %%
a = np.ones(4)
print(a)
# Out:
# [1. 1. 1. 1.]

# %%
a = np.sort([2,3,5,5,6,1])
print(a)
# Out:
# [1 2 3 5 5 6]

# %%
a = np.arange(1,10)
print(a)
# Out:
# [1 2 3 4 5 6 7 8 9]

# %%
import pandas as pd

a = [1, 7, 2]

myvar = pd.Series(a, index = ["x", "y", "z"])

print(myvar)
# Out:
# x    1
# y    7
# z    2
# dtype: int64
